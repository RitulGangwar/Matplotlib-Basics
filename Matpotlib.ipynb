# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
x = np.linspace(0,10, 50)

# %%
y = np.sin(x)

# %%
y
# Out:
# array([ 0.        ,  0.20266794,  0.39692415,  0.57470604,  0.72863478,
#         0.85232157,  0.94063279,  0.98990308,  0.99808748,  0.96484631,
#         0.89155923,  0.78126802,  0.63855032,  0.46932961,  0.2806294 ,
#         0.08028167, -0.12339814, -0.32195632, -0.50715171, -0.67129779,
#        -0.80758169, -0.91034694, -0.97532829, -0.99982867, -0.9828312 ,
#        -0.92504137, -0.82885774, -0.6982724 , -0.53870529, -0.35677924,
#        -0.16004509,  0.04333173,  0.24491007,  0.43632343,  0.6096272 ,
#         0.75762842,  0.8741843 ,  0.9544572 ,  0.99511539,  0.99447137,
#         0.95255185,  0.8710967 ,  0.75348673,  0.60460332,  0.43062587,
#         0.23877532,  0.0370144 , -0.16628279, -0.36267843, -0.54402111])

# %%
x
# Out:
# array([ 0.        ,  0.20408163,  0.40816327,  0.6122449 ,  0.81632653,
#         1.02040816,  1.2244898 ,  1.42857143,  1.63265306,  1.83673469,
#         2.04081633,  2.24489796,  2.44897959,  2.65306122,  2.85714286,
#         3.06122449,  3.26530612,  3.46938776,  3.67346939,  3.87755102,
#         4.08163265,  4.28571429,  4.48979592,  4.69387755,  4.89795918,
#         5.10204082,  5.30612245,  5.51020408,  5.71428571,  5.91836735,
#         6.12244898,  6.32653061,  6.53061224,  6.73469388,  6.93877551,
#         7.14285714,  7.34693878,  7.55102041,  7.75510204,  7.95918367,
#         8.16326531,  8.36734694,  8.57142857,  8.7755102 ,  8.97959184,
#         9.18367347,  9.3877551 ,  9.59183673,  9.79591837, 10.        ])

# %%
plt.plot(x,y)

# %%
plt.xlabel("First Label")
plt.ylabel("second data")
plt.title("My first data plot")
# Out:
# Text(0.5, 1.0, 'My first data plot')

# %%
plt.plot(x,y)
plt.xlabel("First Label")
plt.ylabel("second data")
plt.title("My first data plot")
plt.show()

# %%
x,y
plt.scatter(x,y)

# %%
colours = np.random.rand(50)
plt.scatter(x,y, c= colours)

# %%
colours = np.random.rand(50)
sizes = 700* np.random.rand(50)
plt.scatter(x,y, c= colours, s=sizes)

# %%
x = ["a","b","c","d","e","f","i","j"]
y = np.random.rand(8)
plt.bar(x,y)
# Out:
# <BarContainer object of 8 artists>

# %%
y
# Out:
# array([0.46049441, 0.50042741, 0.76981149, 0.62512244, 0.73197884,
#        0.2281725 , 0.80143042, 0.75581972])

# %%
x = ["a","b","c","d","e","f","i","j"]
y = np.random.rand(8)
plt.barh(x,y)
# Out:
# <BarContainer object of 8 artists>

# %%
x = ["a","b","c","d","e","f","i","j"]
y = np.random.rand(8)
plt.bar(x,y)
# Out:
# <BarContainer object of 8 artists>

# %%
x = np.linspace(0,10, 50)
y = np.sin(x)
plt.plot(x,y, '--b')

# %%
x = np.linspace(0,10, 50)
y = np.sin(x)
plt.plot(x,y, '--b')
plt.grid()
plt.figure(figsize=(5,6))

# %%
d =[1,2,3,4,5,6,1,2,3,8,5,8,2,5,2,1,2,3]

# %%
plt.hist(d)
plt.show()

# %%
x= np.random.rand(50)
y= np.random.rand(50)
z= np.random.rand(50)

fig= plt.figure()
ax =fig.add_subplot(projection = '3d')
ax.scatter(x,y,z)
plt.show()

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]

y = [5, 4, 3, 2, 1]

 

plt.bar(x, y)
# Out:
# <BarContainer object of 5 artists>
